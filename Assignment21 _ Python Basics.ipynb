# %% [markdown]
# # 1. Add the current date to the text file today.txt as a string.

# %%
from datetime import date
now = date.today()
now_str = now.isoformat()
with open('today', 'wt') as output:
    print(now_str, file=output)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2. Read the text file today.txt into the string today_string

# %%
with open('today', 'rt') as input:
    today_string = input.read()

today_string
# Out:
# '2022-06-18\n'

# %% [markdown]
# # 3. Parse the date from today_string.

# %%
fmt = '%Y-%m-%d\n'

import datetime

def convert(date_time):
    format = '%Y-%m-%d\n' 
    datetime_str = datetime.datetime.strptime(date_time, format)

    return datetime_str

print(convert(today_string))
# Out:
# 2022-06-18 00:00:00

# %% [markdown]
# # 4. List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['# Convert categorical variable  to integer value..ipynb',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '01-LinearRegression-A.ipynb',
#  '3D Objects',
#  '61-A-XGBoost-R-01-Copy1.ipynb',
#  '61-A-XGBoost-R-01.ipynb',
#  '61-D-XGBoost-Classifier-04-Copy1.ipynb',
#  '61-D-XGBoost-Classifier-04.ipynb',
#  '63-E-CatBoost-05 Raju Sir As it is.ipynb',
#  '66-B-XGBoostClassification-02.ipynb',
#  '86-A-Bagging-01.ipynb',
#  '86-A-Bagging-02.ipynb',
#  '88-A-VotingClassifier-01.ipynb',
#  '88-Outliers_Different models_Practice.ipynb',
#  'addition.py',
#  'Adult Dataset_Random Forest_Decision Tree_Logistic Regression_Perfect Dont Edit.ipynb',
#  'Adult Dataset_Random Forest_Decision Tree_Logistic Regression_Practice.ipynb',
#  "Algo's.ipynb",
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Assignment10 _ Python Basics.ipynb',
#  'Assignment11 _ Python Basics.ipynb',
# ...

# %% [markdown]
# # 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os
os.listdir('..')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'Logins', 'Public']

# %% [markdown]
# # 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import random 
from datetime import datetime 
from time import sleep
import time

def now1(seconds1):
    time.sleep(seconds1) # delay # wait
    print('Process',i,'wait', seconds1, 'seconds, time is', datetime.datetime.now())

if __name__ == '__main__': 
    for i in range(3):
        seconds1 = random.randint(1,5)
        p1 = multiprocessing.Process(target=now1, args=(seconds1,)) 
        p1.start()
        p1.join()

# %% [markdown]
# # 7. Create a date object of your day of birth.

# %%
import datetime

x = datetime.datetime(1991, 5, 9, 4,30,30)

print(x)
# Out:
# 1991-05-09 04:30:30

# %% [markdown]
# # 8. What day of the week was your day of birth?

# %%
y = x.weekday()
print(y)
# Out:
# 3

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#      0 is Monday and Sunday is 6. So, 3 will be Thursday.

# %% [markdown]
# # 9. When will you be (or when were you) 10,000 days old?

# %%
x = "1991-05-09"
z = datetime.datetime.strptime(x,"%Y-%m-%d")

k = z + datetime.timedelta(days=10000)
print("I will be 10,000 days Old on",k)
# Out:
# I will be 10,000 days Old on 2018-09-24 00:00:00
