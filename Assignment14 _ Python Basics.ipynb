# %% [markdown]
# # 1. What does RGBA stand for?

# %%
# Red-Green-Blue-Alpha

# %% [markdown]
# # 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
# Use rgba.getdata()

# pip install Pillow
from PIL import Image
img = Image.open("image.png")
rgba = img.convert("RGBA")
datas = rgba.getdata()
datas

# %% [markdown]
# # 3. What is a box tuple, and how does it work?

# %%
# Many of Pillow’s functions and methods take a box tuple argument.

# This means Pillow is expecting a tuple of four integer coordinates that 
# represent a rectangular region in an image. 

# The four integers are, in order, as follows:

# Left The x-coordinate of the leftmost edge of the box.

# Top The y-coordinate of the top edge of the box.

# Right The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.

# Bottom The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.

# Note that the box includes the left and top coordinates and goes up to but does not include the right and bottom coordinates.

# For example, the box tuple (3, 1, 9, 6) represents all the pixels in the black box in Figure.

# box tuple (3, 1, 9, 6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
image = Image.open("image.png")
width, height = image.size
print(width, height)
# Out:
# 1331 300

# %% [markdown]
# # 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
# BY Assigning ZERO

from PIL import Image
import numpy as np      
  
img = Image.open(r"tree.jpg").convert('RGB')
img_arr = np.array(img)
img_arr[50 : , 50 : ] = (0, 0, 0)
img = Image.fromarray(img_arr)
img.show()

# %% [markdown]
# # Image before

# %% [markdown]
# ![tree.jpg](attachment:tree.jpg)

# %% [markdown]
# # Image after

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. After making changes to an Image object, how could you save it as an image file?

# %%
# using ".save"  # image_variable.save

from PIL import Image
import numpy as np      
  
img = Image.open(r"tree.jpg").convert('RGB')
img_arr = np.array(img)
img_arr[50 : , 50 : ] = (0, 0, 0)
img = Image.fromarray(img_arr)
img.save("new_tree.jpg")

# %% [markdown]
# # 7. What module contains Pillow’s shape-drawing code?

# %%
# ImageDraw module

from PIL import Image, ImageDraw
img = Image.open('tree.jpg')
draw = ImageDraw.Draw(img)
draw.rectangle(xy = (50, 50, 150, 150),
               fill = (0, 127, 0),
               outline = (255, 255, 255),
               width = 5)
img.save("new_rectangle.jpg")

# %% [markdown]
# # Image Before

# %% [markdown]
# ![tree.jpg](attachment:tree.jpg)

# %% [markdown]
# # Image After

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
# ImageDraw objects have shape-drawing methods such as point(), line(), 
# or rectangle(). 
# They are returned by passing the Image object to the 
# ImageDraw.Draw() function.
